# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.4'

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
soma = arr + 10
print(f"Array após somar 10 = {soma}")
# Out:
# Array após somar 10 = [11 12 13 14 15]

# %%
mult = arr * 2
print(f"Array após somar 10 = {mult}")
# Out:
# Array após somar 10 = [ 2  4  6  8 10]

# %%
media = np.mean(arr)
print(f"Média do Array = {media}")
# Out:
# Média do Array = 3.0
